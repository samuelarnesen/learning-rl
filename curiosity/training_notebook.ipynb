# %%
import sys, pickle, time, math, random

sys.path.append("/usr/local/lib/python3.8/site-packages")

import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np

from ale_py import ALEInterface
from ale_py.roms import Skiing

# %%
sys.path.append("../utils/")

from base_models import *
#from models import *
from base_datasets import *
from stats_collector import StatsCollector

# %%
ale = ALEInterface()
ale.loadROM(Skiing)

env = gym.make("ALE/Breakout-v5")

# %%
class CNNConfig:
    
    def __init__(self, out_channels_one=16, out_channels_two=32, hidden_layer_depth=256, output_depth=3):
        self.out_channels_one = out_channels_one
        self.out_channels_two = out_channels_two
        self.hidden_layer_depth = hidden_layer_depth
        self.output_depth = output_depth
        
class BasicCNN(nn.Module):

    def __init__(self, config):
        super().__init__()
        
        self.preprocessing_pool = nn.MaxPool3d((3, 2, 2))

        self.conv_layer_one = nn.Conv2d(in_channels=1, out_channels=config.out_channels_one, stride=4, kernel_size=8)
        self.pooling_layer_one = nn.AvgPool2d(kernel_size=4)
        self.batch_norm_layer_one = nn.BatchNorm2d(config.out_channels_one)

        self.conv_layer_two = nn.Conv2d(in_channels=config.out_channels_one, out_channels=config.out_channels_two, stride=2, kernel_size=4)
        self.pooling_layer_two = nn.AvgPool1d(kernel_size=2)
        self.batch_norm_layer_two = nn.BatchNorm1d(config.out_channels_two)
        
        self.linear_layer_one = nn.Linear(config.out_channels_two, config.hidden_layer_depth)
        self.batch_norm_layer_three = nn.BatchNorm1d(config.hidden_layer_depth)
        self.linear_layer_two = nn.Linear(config.hidden_layer_depth, config.output_depth) 

    def forward(self, images):
        image_tensor = images if torch.is_tensor(images) else torch.tensor(images).squeeze().unsqueeze(0)
        down_sampled_image_tensor = self.preprocessing_pool(image_tensor.transpose(3, 1).transpose(2, 3).float())
        
        output_one = self.batch_norm_layer_one(F.relu(self.pooling_layer_one(self.conv_layer_one(down_sampled_image_tensor))))
        output_two = self.batch_norm_layer_two(F.relu(self.pooling_layer_two(self.conv_layer_two(output_one).squeeze(-1))).squeeze(-1))
        output_three = self.batch_norm_layer_three(F.relu(self.linear_layer_one(output_two)))
        final_output = self.linear_layer_two(output_three)
        return final_output

    def act(self, images):
        output = self(images)
        return torch.argmax(output, dim=1)

    def evaluate(self, images, actions=None):
        output = self(images)
        if actions != None:
            return torch.stack([output[i, action] for i, action in enumerate(actions)])
        return torch.max(output, dim=1).values

# %%
class CuriousityModule:
    
    def __init__(self):
        pass
    
    def calculate_curiousity_reward(self, images):
        pass
    
    def update(self):
        pass

class RandomNetworkDistillationCuriousityModule(CuriousityModule):
    
    def __init__(self, batch_mode=False):
        super().__init__()
        
        curiousity_config = CNNConfig(8, 16, 32, 8)
        self.target_model = BasicCNN(curiousity_config)
        self.source_model = BasicCNN(curiousity_config)
        self.optimizer = optim.AdamW(self.source_model.parameters(), lr=(1e-3 if batch_mode else 1e-5))
        
        self.target_model.eval()
        self.source_model.eval()
    
    def calculate_curiousity_reward(self, images):
        image_tensor = images if torch.is_tensor(images) else torch.tensor(images).squeeze().unsqueeze(0)
        batch_size, _, _, _ = image_tensor.size()
        with torch.no_grad():
            target = self.target_model(image_tensor)
        source = self.source_model(image_tensor)
        dists = torch.stack([torch.dist(source[i, :], target[i, :]) for i in range(batch_size)])
        return dists
    
    def update(self, images):
        dists = self.calculate_curiousity_reward(images)
        self.optimizer.zero_grad()
        dists.backward()
        self.optimizer.step()
        return dists
    
    def save(self, source_path, target_path):
        save_model(self.source_model, source_path)
        save_model(self.target_model, target_path)
    
    def load(self, source_path, target_path):
        self.source_model = load_model(source_path)
        self.target_model = load_model(target_path)
        self.optimizer = optim.AdamW(self.source_model.parameters(), lr=(1e-3 if batch_mode else 1e-5))
        self.target_model.eval()
        self.source_model.eval()

# %%
MAX_DATASET_SIZE = 100_000
BATCH_SIZE = 64
USE_PRIORITY = False
NUM_EPOCHS = 100_000
DISCOUNT = 0.99
SAVE_PATH = "model.p"
CURIOUSITY_SOURCE_SAVE_PATH = "curious-source-model.p"
CURIOUSITY_TARGET_SAVE_PATH = "curious-target-model.p"
PRINT_FREQUENCY = 1_000
TARGET_UPDATE_FREQUENCY = 250
MODEL_UPDATE_FREQUENCY = 16
TOTAL_FRAMES = 50_000_000
CURIOUSITY_COEFF = 0.0
REGULAR_REWARD_COEFF = 1.0
RELOAD = True

# %%
base_config = CNNConfig(16, 32, 256, 4)
model = BasicCNN(base_config)
curiousity_module = RandomNetworkDistillationCuriousityModule()
if RELOAD:
    model = load_model(SAVE_PATH)
    #curious_module.load(CURIOUSITY_SOURCE_SAVE_PATH, CURIOUSITY_TARGET_SAVE_PATH)
dataset = PrioritizedLog(MAX_DATASET_SIZE) if USE_PRIORITY else SimpleLog(MAX_DATASET_SIZE)
reduction = 'none' if USE_PRIORITY else 'mean'

optimizer = optim.AdamW(model.parameters(), lr=1e-5)
loss_func = nn.MSELoss()
rollout_stats_collector = StatsCollector()
update_stats_collector = StatsCollector()

save_model(model, SAVE_PATH)
target_model = load_model(SAVE_PATH)
curiousity_module.save(CURIOUSITY_SOURCE_SAVE_PATH, CURIOUSITY_TARGET_SAVE_PATH)

# %%
done = False
updates = 0
stuck_count = 0
for frame in range(TOTAL_FRAMES):

    model.eval()

    if frame == 0 or done:
        observation = env.reset()
        done = False

    old_observation = observation
    with torch.no_grad():
        action = model.act(observation)

    observation, reward, done, info = env.step(action.item())
    dataset.add(old_observation, observation, action, reward, done)
    dist = curiousity_module.update(observation)
    
    rollout_stats_collector.add({"Reward": reward, "No-op": 1 if action.item() == 0 else 0, "Fire": 1 if action.item() == 1 else 0, \
                                 "Right": 1 if action.item() == 2 else 0, "Left": 1 if action.item() == 3 else 0, "Curiousity": dist.item()})

    if frame > BATCH_SIZE and frame % MODEL_UPDATE_FREQUENCY == 0:
        model.train()
        
        current_observation_batch, next_observation_batch, action_batch, rewards_batch, incompletions = dataset.sample_batch(BATCH_SIZE)
        
        dists = curiousity_module.calculate_curiousity_reward(next_observation_batch)
        norm_dists = dists * (torch.mean(torch.abs(rewards_batch)).item() / torch.mean(dists).item())
        full_rewards = (REGULAR_REWARD_COEFF * rewards_batch) + (CURIOUSITY_COEFF * norm_dists)
    
        with torch.no_grad():
            target = (DISCOUNT * target_model.evaluate(next_observation_batch).squeeze() * incompletions.squeeze()) + full_rewards
            
        optimizer.zero_grad()
        prediction = model.evaluate(current_observation_batch, action_batch.squeeze())
        loss = loss_func(prediction, target)        
        loss.backward()
        optimizer.step()

        updates += 1
        update_stats_collector.add({"Loss": loss.item(), "Normal Rewards": torch.mean(rewards_batch).item(), \
                                    "Curiousity Rewards": torch.mean(norm_dists).item(), "Min Curiousity": torch.min(norm_dists).item(),\
                                    "Max Curiousity": torch.max(norm_dists).item(), "Total Reward": torch.mean(full_rewards).item(),\
                                    "Max Full Reward": torch.max(full_rewards).item(), "Min Full Reward": torch.min(full_rewards).item()})

    if updates % TARGET_UPDATE_FREQUENCY == 0:
        save_model(model, SAVE_PATH)
        target_model = load_model(SAVE_PATH)
        curiousity_module.save(CURIOUSITY_SOURCE_SAVE_PATH, CURIOUSITY_TARGET_SAVE_PATH)
        updates = 0

    if frame % PRINT_FREQUENCY == 0 or frame == NUM_EPOCHS - 1:
        print(frame, "/", TOTAL_FRAMES)
        rollout_stats_collector.show()
        rollout_stats_collector.reset()
        update_stats_collector.show()
        update_stats_collector.reset()
        print()
# Out:
# 0 / 50000000
# Reward: 0.0, No-op: 0.0, Fire: 0.0, Right: 1.0, Left: 0.0, Curiousity: 6.11
#
#
# 1000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.55, Right: 0.11, Left: 0.0, Curiousity: 3.37
# Loss: 7126.73, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.01, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.38, Min Full Reward: 0.0
#
# 2000 / 50000000
# Reward: 0.01, No-op: 0.3, Fire: 0.62, Right: 0.08, Left: 0.0, Curiousity: 0.24
# Loss: 6078.02, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.56, Min Full Reward: 0.0
#
# 3000 / 50000000
# Reward: 0.01, No-op: 0.3, Fire: 0.62, Right: 0.08, Left: 0.0, Curiousity: 0.2
# Loss: 5785.64, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.53, Min Full Reward: 0.0
#
# 4000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.59, Right: 0.07, Left: 0.0, Curiousity: 0.22
# Loss: 5699.99, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.54, Min Full Reward: 0.0
#
# 5000 / 50000000
# Reward: 0.01, No-op: 0.36, Fire: 0.58, Right: 0.07, Left: 0.0, Curiousity: 0.21
# Loss: 777.32, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 6000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.59, Right: 0.07, Left: 0.0, Curiousity: 0.21
# Loss: 479.48, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 7000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.57, Right: 0.07, Left: 0.0, Curiousity: 0.21
# Loss: 503.62, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 8000 / 50000000
# Reward: 0.01, No-op: 0.33, Fire: 0.61, Right: 0.07, Left: 0.0, Curiousity: 0.2
# Loss: 460.28, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.51, Min Full Reward: 0.0
#
# 9000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.58, Right: 0.07, Left: 0.0, Curiousity: 0.19
# Loss: 358.04, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.47, Min Full Reward: 0.0
#
# 10000 / 50000000
# Reward: 0.01, No-op: 0.33, Fire: 0.6, Right: 0.08, Left: 0.0, Curiousity: 0.19
# Loss: 347.28, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.54, Min Full Reward: 0.0
#
# 11000 / 50000000
# Reward: 0.01, No-op: 0.33, Fire: 0.59, Right: 0.08, Left: 0.0, Curiousity: 0.18
# Loss: 336.0, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.48, Min Full Reward: 0.0
#
# 12000 / 50000000
# Reward: 0.01, No-op: 0.38, Fire: 0.54, Right: 0.08, Left: 0.0, Curiousity: 0.19
# Loss: 306.93, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.49, Min Full Reward: 0.0
#
# 13000 / 50000000
# Reward: 0.0, No-op: 0.71, Fire: 0.26, Right: 0.03, Left: 0.0, Curiousity: 0.08
# Loss: 252.06, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.45, Min Full Reward: 0.0
#
# 14000 / 50000000
# Reward: 0.01, No-op: 0.43, Fire: 0.5, Right: 0.07, Left: 0.0, Curiousity: 0.17
# Loss: 230.86, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.46, Min Full Reward: 0.0
#
# 15000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.56, Right: 0.08, Left: 0.0, Curiousity: 0.19
# Loss: 248.56, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.42, Min Full Reward: 0.0
#
# 16000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.57, Right: 0.08, Left: 0.0, Curiousity: 0.19
# Loss: 228.65, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.43, Min Full Reward: 0.0
#
# 17000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.59, Right: 0.07, Left: 0.0, Curiousity: 0.18
# Loss: 210.41, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.52, Min Full Reward: 0.0
#
# 18000 / 50000000
# Reward: 0.01, No-op: 0.43, Fire: 0.49, Right: 0.08, Left: 0.0, Curiousity: 0.17
# Loss: 206.35, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.49, Min Full Reward: 0.0
#
# 19000 / 50000000
# Reward: 0.01, No-op: 0.33, Fire: 0.59, Right: 0.08, Left: 0.0, Curiousity: 0.17
# Loss: 213.4, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.5, Min Full Reward: 0.0
#
# 20000 / 50000000
# Reward: 0.01, No-op: 0.32, Fire: 0.6, Right: 0.08, Left: 0.0, Curiousity: 0.16
# Loss: 191.79, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.43, Min Full Reward: 0.0
#
# 21000 / 50000000
# Reward: 0.01, No-op: 0.32, Fire: 0.6, Right: 0.08, Left: 0.0, Curiousity: 0.16
# Loss: 173.28, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.5, Min Full Reward: 0.0
#
# 22000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.57, Right: 0.08, Left: 0.0, Curiousity: 0.17
# Loss: 163.53, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 23000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.57, Right: 0.08, Left: 0.0, Curiousity: 0.18
# Loss: 168.53, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 24000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.58, Right: 0.08, Left: 0.0, Curiousity: 0.17
# Loss: 160.51, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.41, Min Full Reward: 0.0
#
# 25000 / 50000000
# Reward: 0.01, No-op: 0.36, Fire: 0.56, Right: 0.08, Left: 0.0, Curiousity: 0.18
# Loss: 162.69, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.56, Min Full Reward: 0.0
#
# 26000 / 50000000
# Reward: 0.01, No-op: 0.32, Fire: 0.6, Right: 0.08, Left: 0.0, Curiousity: 0.16
# Loss: 160.05, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.51, Min Full Reward: 0.0
#
# 27000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.56, Right: 0.08, Left: 0.0, Curiousity: 0.17
# Loss: 146.81, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.47, Min Full Reward: 0.0
#
# 28000 / 50000000
# Reward: 0.01, No-op: 0.38, Fire: 0.54, Right: 0.08, Left: 0.0, Curiousity: 0.16
# Loss: 127.82, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.54, Min Full Reward: 0.0
#
# 29000 / 50000000
# Reward: 0.01, No-op: 0.41, Fire: 0.51, Right: 0.08, Left: 0.0, Curiousity: 0.16
# Loss: 120.45, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.48, Min Full Reward: 0.0
#
# 30000 / 50000000
# Reward: 0.01, No-op: 0.55, Fire: 0.39, Right: 0.06, Left: 0.0, Curiousity: 0.11
# Loss: 115.45, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.49, Min Full Reward: 0.0
#
# 31000 / 50000000
# Reward: 0.01, No-op: 0.4, Fire: 0.51, Right: 0.09, Left: 0.0, Curiousity: 0.17
# Loss: 116.3, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.6, Min Full Reward: 0.0
# 32000 / 50000000
# Reward: 0.01, No-op: 0.56, Fire: 0.37, Right: 0.07, Left: 0.0, Curiousity: 0.12
# Loss: 108.19, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 33000 / 50000000
# Reward: 0.01, No-op: 0.49, Fire: 0.43, Right: 0.08, Left: 0.0, Curiousity: 0.14
# Loss: 93.88, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.44, Min Full Reward: 0.0
#
# 34000 / 50000000
# Reward: 0.0, No-op: 0.69, Fire: 0.26, Right: 0.04, Left: 0.0, Curiousity: 0.08
# Loss: 93.55, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.43, Min Full Reward: 0.0
#
# 35000 / 50000000
# Reward: 0.0, No-op: 0.85, Fire: 0.13, Right: 0.02, Left: 0.0, Curiousity: 0.04
# Loss: 88.46, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.55, Min Full Reward: 0.0
#
# 36000 / 50000000
# Reward: 0.0, No-op: 0.89, Fire: 0.1, Right: 0.02, Left: 0.0, Curiousity: 0.03
# Loss: 85.33, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.49, Min Full Reward: 0.0
#
# 37000 / 50000000
# Reward: 0.0, No-op: 0.86, Fire: 0.12, Right: 0.02, Left: 0.0, Curiousity: 0.04
# Loss: 91.44, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.53, Min Full Reward: 0.0
#
# 38000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 88.47, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.41, Min Full Reward: 0.0
#
# 39000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 80.02, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.58, Min Full Reward: 0.0
#
# 40000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 69.34, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.51, Min Full Reward: 0.0
#
# 41000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 75.07, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 42000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 67.02, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 43000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 65.07, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 44000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 64.17, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.41, Min Full Reward: 0.0
#
# 45000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 64.96, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.5, Min Full Reward: 0.0
#
# 46000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 56.69, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.3, Min Full Reward: 0.0
#
# 47000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 57.98, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 48000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 56.79, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.43, Min Full Reward: 0.0
#
# 49000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 66.7, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.37, Min Full Reward: 0.0
#
# 50000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 71.33, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.38, Min Full Reward: 0.0
#
# 51000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 65.11, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.34, Min Full Reward: 0.0
#
# 52000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 59.72, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 53000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 57.32, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.39, Min Full Reward: 0.0
#
# 54000 / 50000000
# Reward: 0.0, No-op: 0.73, Fire: 0.06, Right: 0.21, Left: 0.0, Curiousity: 0.43
# Loss: 70.93, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 55000 / 50000000
# Reward: 0.0, No-op: 0.86, Fire: 0.02, Right: 0.11, Left: 0.0, Curiousity: 0.32
# Loss: 66.9, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 56000 / 50000000
# Reward: 0.0, No-op: 0.9, Fire: 0.0, Right: 0.1, Left: 0.0, Curiousity: 0.19
# Loss: 69.48, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 57000 / 50000000
# Reward: 0.0, No-op: 0.92, Fire: 0.0, Right: 0.08, Left: 0.0, Curiousity: 0.15
# Loss: 62.01, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 58000 / 50000000
# Reward: 0.0, No-op: 0.94, Fire: 0.0, Right: 0.06, Left: 0.0, Curiousity: 0.23
# Loss: 59.14, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 59000 / 50000000
# Reward: 0.0, No-op: 0.96, Fire: 0.0, Right: 0.04, Left: 0.0, Curiousity: 0.19
# Loss: 58.44, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.0, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 60000 / 50000000
# Reward: 0.0, No-op: 0.96, Fire: 0.0, Right: 0.04, Left: 0.0, Curiousity: 0.36
# Loss: 66.98, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 61000 / 50000000
# Reward: 0.0, No-op: 0.94, Fire: 0.0, Right: 0.06, Left: 0.0, Curiousity: 0.32
# Loss: 53.87, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 62000 / 50000000
# Reward: 0.0, No-op: 0.87, Fire: 0.06, Right: 0.06, Left: 0.0, Curiousity: 0.32
# Loss: 46.42, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.33, Min Full Reward: 0.0
#
# 63000 / 50000000
# Reward: 0.0, No-op: 0.94, Fire: 0.06, Right: 0.0, Left: 0.0, Curiousity: 0.21
# Loss: 52.13, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.01, Total Reward: 0.01, Max Full Reward: 0.26, Min Full Reward: 0.0
# 64000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.26
# Loss: 51.13, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.02, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 65000 / 50000000
# Reward: 0.01, No-op: 0.58, Fire: 0.31, Right: 0.11, Left: 0.0, Curiousity: 0.11
# Loss: 38.72, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.01, Max Full Reward: 0.37, Min Full Reward: 0.0
#
# 66000 / 50000000
# Reward: 0.01, No-op: 0.23, Fire: 0.6, Right: 0.17, Left: 0.0, Curiousity: 0.17
# Loss: 36.68, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.01, Max Full Reward: 0.3, Min Full Reward: 0.0
#
# 67000 / 50000000
# Reward: 0.01, No-op: 0.33, Fire: 0.52, Right: 0.16, Left: 0.0, Curiousity: 0.16
# Loss: 36.68, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.01, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 68000 / 50000000
# Reward: 0.01, No-op: 0.23, Fire: 0.6, Right: 0.17, Left: 0.0, Curiousity: 0.17
# Loss: 33.52, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 69000 / 50000000
# Reward: 0.01, No-op: 0.24, Fire: 0.6, Right: 0.17, Left: 0.0, Curiousity: 0.16
# Loss: 45.58, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.01, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 70000 / 50000000
# Reward: 0.01, No-op: 0.23, Fire: 0.6, Right: 0.17, Left: 0.0, Curiousity: 0.17
# Loss: 42.52, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.0, Max Full Reward: 0.21, Min Full Reward: 0.0
#
# 71000 / 50000000
# Reward: 0.01, No-op: 0.22, Fire: 0.61, Right: 0.17, Left: 0.0, Curiousity: 0.16
# Loss: 37.14, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.34, Min Full Reward: 0.0
#
# 72000 / 50000000
# Reward: 0.01, No-op: 0.24, Fire: 0.6, Right: 0.16, Left: 0.0, Curiousity: 0.15
# Loss: 42.8, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 73000 / 50000000
# Reward: 0.01, No-op: 0.25, Fire: 0.58, Right: 0.17, Left: 0.0, Curiousity: 0.16
# Loss: 46.2, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 74000 / 50000000
# Reward: 0.01, No-op: 0.23, Fire: 0.61, Right: 0.16, Left: 0.0, Curiousity: 0.15
# Loss: 40.62, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 75000 / 50000000
# Reward: 0.01, No-op: 0.23, Fire: 0.62, Right: 0.15, Left: 0.0, Curiousity: 0.14
# Loss: 38.33, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 76000 / 50000000
# Reward: 0.0, No-op: 0.82, Fire: 0.14, Right: 0.03, Left: 0.0, Curiousity: 0.04
# Loss: 42.43, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 77000 / 50000000
# Reward: 0.01, No-op: 0.24, Fire: 0.59, Right: 0.17, Left: 0.0, Curiousity: 0.16
# Loss: 33.44, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 78000 / 50000000
# Reward: 0.01, No-op: 0.29, Fire: 0.56, Right: 0.15, Left: 0.0, Curiousity: 0.14
# Loss: 31.9, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.0, Max Full Reward: 0.19, Min Full Reward: 0.0
#
# 79000 / 50000000
# Reward: 0.01, No-op: 0.31, Fire: 0.53, Right: 0.16, Left: 0.0, Curiousity: 0.16
# Loss: 30.45, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 80000 / 50000000
# Reward: 0.01, No-op: 0.28, Fire: 0.58, Right: 0.14, Left: 0.0, Curiousity: 0.14
# Loss: 28.03, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.37, Min Full Reward: 0.0
#
# 81000 / 50000000
# Reward: 0.01, No-op: 0.47, Fire: 0.42, Right: 0.11, Left: 0.0, Curiousity: 0.11
# Loss: 24.03, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.34, Min Full Reward: 0.0
#
# 82000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 26.33, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 83000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 25.85, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 84000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 26.75, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.41, Min Full Reward: 0.0
#
# 85000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 28.24, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 86000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 24.06, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 87000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 26.15, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 88000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 25.89, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.3, Min Full Reward: 0.0
#
# 89000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 26.96, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 90000 / 50000000
# Reward: 0.01, No-op: 0.54, Fire: 0.36, Right: 0.09, Left: 0.0, Curiousity: 0.09
# Loss: 32.41, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 91000 / 50000000
# Reward: 0.0, No-op: 0.71, Fire: 0.23, Right: 0.06, Left: 0.0, Curiousity: 0.06
# Loss: 23.11, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.31, Min Full Reward: 0.0
#
# 92000 / 50000000
# Reward: 0.01, No-op: 0.47, Fire: 0.4, Right: 0.12, Left: 0.0, Curiousity: 0.12
# Loss: 26.7, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 93000 / 50000000
# Reward: 0.01, No-op: 0.44, Fire: 0.45, Right: 0.12, Left: 0.0, Curiousity: 0.12
# Loss: 17.67, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 94000 / 50000000
# Reward: 0.01, No-op: 0.67, Fire: 0.25, Right: 0.08, Left: 0.0, Curiousity: 0.07
# Loss: 24.9, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 95000 / 50000000
# Reward: 0.0, No-op: 0.67, Fire: 0.27, Right: 0.06, Left: 0.0, Curiousity: 0.08
# Loss: 23.68, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.29, Min Full Reward: 0.0
# 96000 / 50000000
# Reward: 0.01, No-op: 0.6, Fire: 0.32, Right: 0.08, Left: 0.0, Curiousity: 0.09
# Loss: 23.1, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 97000 / 50000000
# Reward: 0.0, No-op: 0.87, Fire: 0.1, Right: 0.03, Left: 0.0, Curiousity: 0.03
# Loss: 19.64, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 98000 / 50000000
# Reward: 0.0, No-op: 0.85, Fire: 0.12, Right: 0.03, Left: 0.0, Curiousity: 0.03
# Loss: 19.33, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 99000 / 50000000
# Reward: 0.0, No-op: 0.87, Fire: 0.11, Right: 0.02, Left: 0.0, Curiousity: 0.03
# Loss: 17.64, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 99999 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 18.53, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 100000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 6.09, Normal Rewards: 0.02, Curiousity Rewards: 0.02, Min Curiousity: 0.0, Max Curiousity: 0.1, Total Reward: 0.02, Max Full Reward: 1.0, Min Full Reward: 0.0
#
# 101000 / 50000000
# Reward: 0.0, No-op: 0.93, Fire: 0.05, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 17.14, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 102000 / 50000000
# Reward: 0.01, No-op: 0.69, Fire: 0.24, Right: 0.06, Left: 0.0, Curiousity: 0.07
# Loss: 18.5, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.3, Min Full Reward: 0.0
#
# 103000 / 50000000
# Reward: 0.0, No-op: 0.81, Fire: 0.15, Right: 0.04, Left: 0.0, Curiousity: 0.04
# Loss: 19.24, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.34, Min Full Reward: 0.0
#
# 104000 / 50000000
# Reward: 0.01, No-op: 0.56, Fire: 0.36, Right: 0.07, Left: 0.0, Curiousity: 0.08
# Loss: 19.01, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.03, Total Reward: 0.0, Max Full Reward: 0.21, Min Full Reward: 0.0
#
# 105000 / 50000000
# Reward: 0.0, No-op: 0.71, Fire: 0.23, Right: 0.06, Left: 0.0, Curiousity: 0.06
# Loss: 16.13, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 106000 / 50000000
# Reward: 0.01, No-op: 0.7, Fire: 0.24, Right: 0.07, Left: 0.0, Curiousity: 0.07
# Loss: 18.01, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.22, Min Full Reward: 0.0
#
# 107000 / 50000000
# Reward: 0.0, No-op: 0.71, Fire: 0.23, Right: 0.06, Left: 0.0, Curiousity: 0.06
# Loss: 16.75, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.39, Min Full Reward: 0.0
#
# 108000 / 50000000
# Reward: 0.01, No-op: 0.62, Fire: 0.3, Right: 0.08, Left: 0.0, Curiousity: 0.08
# Loss: 16.29, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.37, Min Full Reward: 0.0
#
# 109000 / 50000000
# Reward: 0.0, No-op: 0.72, Fire: 0.23, Right: 0.05, Left: 0.0, Curiousity: 0.06
# Loss: 19.53, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 110000 / 50000000
# Reward: 0.01, No-op: 0.6, Fire: 0.33, Right: 0.07, Left: 0.0, Curiousity: 0.08
# Loss: 19.94, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.33, Min Full Reward: 0.0
#
# 111000 / 50000000
# Reward: 0.01, No-op: 0.69, Fire: 0.23, Right: 0.08, Left: 0.0, Curiousity: 0.08
# Loss: 18.45, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 112000 / 50000000
# Reward: 0.0, No-op: 0.83, Fire: 0.12, Right: 0.05, Left: 0.0, Curiousity: 0.04
# Loss: 19.05, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.01, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 113000 / 50000000
# Reward: 0.0, No-op: 0.73, Fire: 0.21, Right: 0.06, Left: 0.0, Curiousity: 0.06
# Loss: 17.12, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.19, Min Full Reward: 0.0
#
# 114000 / 50000000
# Reward: 0.0, No-op: 0.77, Fire: 0.17, Right: 0.05, Left: 0.0, Curiousity: 0.05
# Loss: 15.58, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.22, Min Full Reward: 0.0
#
# 115000 / 50000000
# Reward: 0.0, No-op: 0.93, Fire: 0.05, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 18.69, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.23, Min Full Reward: 0.0
#
# 116000 / 50000000
# Reward: 0.0, No-op: 0.8, Fire: 0.17, Right: 0.03, Left: 0.0, Curiousity: 0.04
# Loss: 14.79, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.08, Total Reward: 0.01, Max Full Reward: 0.44, Min Full Reward: 0.0
#
# 117000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 18.87, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.34, Min Full Reward: 0.0
#
# 118000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 19.88, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 119000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 17.32, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 120000 / 50000000
# Reward: 0.0, No-op: 0.86, Fire: 0.11, Right: 0.02, Left: 0.0, Curiousity: 0.03
# Loss: 17.97, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 121000 / 50000000
# Reward: 0.01, No-op: 0.45, Fire: 0.43, Right: 0.12, Left: 0.0, Curiousity: 0.11
# Loss: 62.99, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 122000 / 50000000
# Reward: 0.01, No-op: 0.53, Fire: 0.37, Right: 0.1, Left: 0.0, Curiousity: 0.11
# Loss: 58.25, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 123000 / 50000000
# Reward: 0.01, No-op: 0.52, Fire: 0.39, Right: 0.09, Left: 0.0, Curiousity: 0.1
# Loss: 50.37, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 124000 / 50000000
# Reward: 0.01, No-op: 0.5, Fire: 0.39, Right: 0.11, Left: 0.0, Curiousity: 0.1
# Loss: 42.38, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 125000 / 50000000
# Reward: 0.0, No-op: 0.73, Fire: 0.22, Right: 0.05, Left: 0.0, Curiousity: 0.05
# Loss: 26.45, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.31, Min Full Reward: 0.0
#
# 126000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 30.38, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.24, Min Full Reward: 0.0
# 127000 / 50000000
# Reward: 0.0, No-op: 0.84, Fire: 0.12, Right: 0.03, Left: 0.0, Curiousity: 0.04
# Loss: 28.27, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 128000 / 50000000
# Reward: 0.0, No-op: 0.91, Fire: 0.07, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 36.34, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.22, Min Full Reward: 0.0
#
# 129000 / 50000000
# Reward: 0.01, No-op: 0.52, Fire: 0.37, Right: 0.11, Left: 0.0, Curiousity: 0.11
# Loss: 62.1, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 130000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.53, Right: 0.13, Left: 0.0, Curiousity: 0.13
# Loss: 37.07, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 131000 / 50000000
# Reward: 0.01, No-op: 0.53, Fire: 0.36, Right: 0.12, Left: 0.0, Curiousity: 0.1
# Loss: 54.85, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 132000 / 50000000
# Reward: 0.01, No-op: 0.34, Fire: 0.52, Right: 0.14, Left: 0.0, Curiousity: 0.13
# Loss: 53.79, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 133000 / 50000000
# Reward: 0.0, No-op: 0.73, Fire: 0.22, Right: 0.05, Left: 0.0, Curiousity: 0.05
# Loss: 36.5, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.04, Total Reward: 0.0, Max Full Reward: 0.18, Min Full Reward: 0.0
#
# 134000 / 50000000
# Reward: 0.0, No-op: 0.95, Fire: 0.04, Right: 0.0, Left: 0.0, Curiousity: 0.02
# Loss: 32.94, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 135000 / 50000000
# Reward: 0.0, No-op: 0.72, Fire: 0.23, Right: 0.05, Left: 0.0, Curiousity: 0.06
# Loss: 37.92, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 136000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 40.16, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 137000 / 50000000
# Reward: 0.01, No-op: 0.44, Fire: 0.44, Right: 0.12, Left: 0.0, Curiousity: 0.11
# Loss: 38.15, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 138000 / 50000000
# Reward: 0.01, No-op: 0.66, Fire: 0.28, Right: 0.06, Left: 0.0, Curiousity: 0.07
# Loss: 35.46, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.0, Max Full Reward: 0.24, Min Full Reward: 0.0
#
# 139000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 30.94, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 140000 / 50000000
# Reward: 0.0, No-op: 0.77, Fire: 0.19, Right: 0.04, Left: 0.0, Curiousity: 0.05
# Loss: 30.21, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 141000 / 50000000
# Reward: 0.01, No-op: 0.42, Fire: 0.47, Right: 0.11, Left: 0.0, Curiousity: 0.12
# Loss: 46.13, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.08, Total Reward: 0.01, Max Full Reward: 0.35, Min Full Reward: 0.0
#
# 142000 / 50000000
# Reward: 0.01, No-op: 0.41, Fire: 0.48, Right: 0.11, Left: 0.0, Curiousity: 0.11
# Loss: 67.48, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 143000 / 50000000
# Reward: 0.01, No-op: 0.35, Fire: 0.54, Right: 0.11, Left: 0.0, Curiousity: 0.12
# Loss: 41.84, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.1, Total Reward: 0.01, Max Full Reward: 0.4, Min Full Reward: 0.0
#
# 144000 / 50000000
# Reward: 0.01, No-op: 0.42, Fire: 0.47, Right: 0.1, Left: 0.0, Curiousity: 0.11
# Loss: 55.57, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.33, Min Full Reward: 0.0
#
# 145000 / 50000000
# Reward: 0.0, No-op: 0.8, Fire: 0.17, Right: 0.03, Left: 0.0, Curiousity: 0.04
# Loss: 64.19, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 146000 / 50000000
# Reward: 0.01, No-op: 0.63, Fire: 0.31, Right: 0.07, Left: 0.0, Curiousity: 0.07
# Loss: 43.18, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 147000 / 50000000
# Reward: 0.01, No-op: 0.47, Fire: 0.44, Right: 0.1, Left: 0.0, Curiousity: 0.09
# Loss: 57.0, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 148000 / 50000000
# Reward: 0.01, No-op: 0.4, Fire: 0.48, Right: 0.12, Left: 0.0, Curiousity: 0.12
# Loss: 65.02, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.27, Min Full Reward: 0.0
#
# 149000 / 50000000
# Reward: 0.01, No-op: 0.56, Fire: 0.36, Right: 0.08, Left: 0.0, Curiousity: 0.08
# Loss: 53.69, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.01, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 150000 / 50000000
# Reward: 0.0, No-op: 0.81, Fire: 0.16, Right: 0.03, Left: 0.0, Curiousity: 0.04
# Loss: 44.8, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 151000 / 50000000
# Reward: 0.0, No-op: 1.0, Fire: 0.0, Right: 0.0, Left: 0.0, Curiousity: 0.0
# Loss: 35.23, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.1, Total Reward: 0.01, Max Full Reward: 0.32, Min Full Reward: 0.0
#
# 152000 / 50000000
# Reward: 0.01, No-op: 0.5, Fire: 0.42, Right: 0.08, Left: 0.0, Curiousity: 0.09
# Loss: 35.39, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 153000 / 50000000
# Reward: 0.01, No-op: 0.46, Fire: 0.45, Right: 0.1, Left: 0.0, Curiousity: 0.1
# Loss: 34.76, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.01, Max Full Reward: 0.31, Min Full Reward: 0.0
#
# 154000 / 50000000
# Reward: 0.01, No-op: 0.61, Fire: 0.32, Right: 0.07, Left: 0.0, Curiousity: 0.07
# Loss: 35.43, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.07, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
#
# 155000 / 50000000
# Reward: 0.0, No-op: 0.9, Fire: 0.09, Right: 0.01, Left: 0.0, Curiousity: 0.02
# Loss: 31.67, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.08, Total Reward: 0.01, Max Full Reward: 0.31, Min Full Reward: 0.0
#
# 156000 / 50000000
# Reward: 0.0, No-op: 0.87, Fire: 0.11, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 27.59, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.1, Total Reward: 0.01, Max Full Reward: 0.41, Min Full Reward: 0.0
#
# 157000 / 50000000
# Reward: 0.0, No-op: 0.89, Fire: 0.09, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 45.3, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.09, Total Reward: 0.01, Max Full Reward: 0.39, Min Full Reward: 0.0
#
# 158000 / 50000000
# Reward: 0.01, No-op: 0.61, Fire: 0.33, Right: 0.06, Left: 0.0, Curiousity: 0.07
# Loss: 48.1, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.25, Min Full Reward: 0.0
# 159000 / 50000000
# Reward: 0.0, No-op: 0.86, Fire: 0.11, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 46.91, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.05, Total Reward: 0.0, Max Full Reward: 0.26, Min Full Reward: 0.0
#
# 160000 / 50000000
# Reward: 0.0, No-op: 0.88, Fire: 0.1, Right: 0.02, Left: 0.0, Curiousity: 0.02
# Loss: 33.61, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.1, Total Reward: 0.01, Max Full Reward: 0.33, Min Full Reward: 0.0
#
# 161000 / 50000000
# Reward: 0.01, No-op: 0.53, Fire: 0.37, Right: 0.1, Left: 0.0, Curiousity: 0.08
# Loss: 51.35, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.1, Total Reward: 0.01, Max Full Reward: 0.37, Min Full Reward: 0.0
#
# 162000 / 50000000
# Reward: 0.01, No-op: 0.46, Fire: 0.43, Right: 0.11, Left: 0.0, Curiousity: 0.1
# Loss: 89.75, Normal Rewards: 0.0, Curiousity Rewards: 0.0, Min Curiousity: 0.0, Max Curiousity: 0.06, Total Reward: 0.0, Max Full Reward: 0.29, Min Full Reward: 0.0
#
# 163000 / 50000000
# Reward: 0.01, No-op: 0.54, Fire: 0.38, Right: 0.07, Left: 0.0, Curiousity: 0.08
# Loss: 48.96, Normal Rewards: 0.01, Curiousity Rewards: 0.01, Min Curiousity: 0.0, Max Curiousity: 0.09, Total Reward: 0.01, Max Full Reward: 0.39, Min Full Reward: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 4>()
#      13 with torch.no_grad():
#      14     action = model.act(observation)
# ---> 16 observation, reward, done, info = env.step(action.item())
#      17 dataset.add(old_observation, observation, action, reward, done)
#      18 dist = curiousity_module.update(observation)
#
# File /usr/local/lib/python3.8/site-packages/gym/wrappers/time_limit.py:49, in TimeLimit.step(self, action)
#      38 def step(self, action):
#      39     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      40
#      41     Args:
#    (...)
#      47         "TimeLimit.truncated"=False if the environment terminated
#      48     """
# ---> 49     observation, reward, done, info = self.env.step(action)
#      50     self._elapsed_steps += 1
#      51     if self._elapsed_steps >= self._max_episode_steps:
#
# File /usr/local/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File /usr/local/lib/python3.8/site-packages/gym/envs/atari/environment.py:238, in AtariEnv.step(self, action_ind)
#     236 reward = 0.0
#     237 for _ in range(frameskip):
# --> 238     reward += self.ale.act(action)
#     240 return self._get_obs(), reward, terminal, self._get_info()
#
# KeyboardInterrupt:

# %%
render_env = gym.make("ALE/Breakout-v5", render_mode='human')
max_actions = 1_000
model.eval()
observation = render_env.reset()
steps = 0
while not done  and steps < max_actions:
    model.eval()
    with torch.no_grad():
        action = model.act(observation)
    if steps == 0:
        action = torch.tensor([1])
    #dist = curiousity_module.update(observation)
    observation, reward, done, info = render_env.step(action.item())
    #print(i, action.item(), done)
    steps += 1
